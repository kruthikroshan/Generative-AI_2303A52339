# %% [markdown]
# <a href="https://colab.research.google.com/github/kruthikroshan/Generative-AI_2303A52339/blob/main/GenAI_Assignment_5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME: KRUTHIK ROSHAN
#
# BATCH >> 41
#
# 2303A52339

# %%
import numpy as np
# Training Data (from Table 1)
X_train = np.array([[1, 2], [2, 3], [5, 6], [6, 7], [7, 8], [8, 9]])
y_train = np.array([[0.4140], [0.4611], [0.5501], [0.5656], [0.5765], [0.5840]])

# Test Data (from Table 2)
X_test = np.array([[3, 4], [4, 5]])
y_test = np.array([[0.4992], [0.5285]])

# Initialize weights and biases
np.random.seed(42)
input_size = 2
hidden_size = 4
output_size = 1
learning_rate = 0.01

W1 = np.random.randn(input_size, hidden_size)
b1 = np.zeros((1, hidden_size))
W2 = np.random.randn(hidden_size, output_size)
b2 = np.zeros((1, output_size))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

def forward_propagation(X):
    Z1 = np.dot(X, W1) + b1
    A1 = sigmoid(Z1)
    Z2 = np.dot(A1, W2) + b2
    A2 = Z2  # Linear activation for output layer
    return Z1, A1, Z2, A2

def backward_propagation(X, y, Z1, A1, Z2, A2):
    global W1, b1, W2, b2

    m = X.shape[0]
    dZ2 = A2 - y  # Derivative of loss w.r.t. output
    dW2 = np.dot(A1.T, dZ2) / m
    db2 = np.sum(dZ2, axis=0, keepdims=True) / m

    dZ1 = np.dot(dZ2, W2.T) * sigmoid_derivative(A1)
    dW1 = np.dot(X.T, dZ1) / m
    db1 = np.sum(dZ1, axis=0, keepdims=True) / m

    # Update weights and biases
    W1 -= learning_rate * dW1
    b1 -= learning_rate * db1
    W2 -= learning_rate * dW2
    b2 -= learning_rate * db2

def train(X, y, epochs=10000):
    for i in range(epochs):
        Z1, A1, Z2, A2 = forward_propagation(X)
        backward_propagation(X, y, Z1, A1, Z2, A2)
        if i % 1000 == 0:
            mse = np.mean((A2 - y) ** 2)
            print(f"Epoch {i}, MSE: {mse:.6f}")

def predict(X):
    _, _, _, A2 = forward_propagation(X)
    return A2

# Train the model
train(X_train, y_train)

# Evaluate on test data
y_pred_test = predict(X_test)
test_mse = np.mean((y_pred_test - y_test) ** 2)
print(f"Test MSE: {test_mse:.6f}")

# User Input for Prediction
x1, x2 = map(float, input("Enter values for x1 and x2: ").split())
import numpy as np
# Training Data (from Table 1)
X_train = np.array([[1, 2], [2, 3], [5, 6], [6, 7], [7, 8], [8, 9]])
y_train = np.array([[0.4140], [0.4611], [0.5501], [0.5656], [0.5765], [0.5840]])

# Test Data (from Table 2)
X_test = np.array([[3, 4], [4, 5]])
y_test = np.array([[0.4992], [0.5285]])

# Initialize weights and biases
np.random.seed(42)
input_size = 2
hidden_size = 4
output_size = 1
learning_rate = 0.01

W1 = np.random.randn(input_size, hidden_size)
b1 = np.zeros((1, hidden_size))
W2 = np.random.randn(hidden_size, output_size)
b2 = np.zeros((1, output_size))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

def forward_propagation(X):
    Z1 = np.dot(X, W1) + b1
    A1 = sigmoid(Z1)
    Z2 = np.dot(A1, W2) + b2
    A2 = Z2  # Linear activation for output layer
    return Z1, A1, Z2, A2

def backward_propagation(X, y, Z1, A1, Z2, A2):
    global W1, b1, W2, b2

    m = X.shape[0]
    dZ2 = A2 - y  # Derivative of loss w.r.t. output
    dW2 = np.dot(A1.T, dZ2) / m
    db2 = np.sum(dZ2, axis=0, keepdims=True) / m

    dZ1 = np.dot(dZ2, W2.T) * sigmoid_derivative(A1)
    dW1 = np.dot(X.T, dZ1) / m
    db1 = np.sum(dZ1, axis=0, keepdims=True) / m

    # Update weights and biases
    W1 -= learning_rate * dW1
    b1 -= learning_rate * db1
    W2 -= learning_rate * dW2
    b2 -= learning_rate * db2

def train(X, y, epochs=10000):
    for i in range(epochs):
        Z1, A1, Z2, A2 = forward_propagation(X)
        backward_propagation(X, y, Z1, A1, Z2, A2)
        if i % 1000 == 0:
            mse = np.mean((A2 - y) ** 2)
            print(f"Epoch {i}, MSE: {mse:.6f}")

def predict(X):
    _, _, _, A2 = forward_propagation(X)
    return A2

# Train the model
train(X_train, y_train)

# Evaluate on test data
y_pred_test = predict(X_test)
test_mse = np.mean((y_pred_test - y_test) ** 2)
print(f"Test MSE: {test_mse:.6f}")

# User Input for Prediction
x1, x2 = map(float, input("Enter values for x1 and x2: ").split())
user_input = np.array([[x1, x2]])
prediction = predict(user_input)
print(f"Predicted Output: {prediction[0][0]:.6f}")
# Out:
# Epoch 0, MSE: 2.945074
# Epoch 1000, MSE: 0.000232
# Epoch 2000, MSE: 0.000175
# Epoch 3000, MSE: 0.000171
# Epoch 4000, MSE: 0.000170
# Epoch 5000, MSE: 0.000169
# Epoch 6000, MSE: 0.000169
# Epoch 7000, MSE: 0.000168
# Epoch 8000, MSE: 0.000168
# Epoch 9000, MSE: 0.000167
# Test MSE: 0.000436
# Enter values for x1 and x2: 5 6
# Epoch 0, MSE: 2.945074
# Epoch 1000, MSE: 0.000232
# Epoch 2000, MSE: 0.000175
# Epoch 3000, MSE: 0.000171
# Epoch 4000, MSE: 0.000170
# Epoch 5000, MSE: 0.000169
# Epoch 6000, MSE: 0.000169
# Epoch 7000, MSE: 0.000168
# Epoch 8000, MSE: 0.000168
# Epoch 9000, MSE: 0.000167
# Test MSE: 0.000436
# Enter values for x1 and x2: 5 2
# Predicted Output: 0.395167
